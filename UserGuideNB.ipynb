# %% [markdown]
# # THIES Binary Processor - User guide notebook

# %% [markdown]
# THIES DL16 exports two types of data in two different directories:
# * `ARCH_AV1` for avarage values of a 10 min span. Contains parameters of DataType Float. (We will refer to it as AV Data.)
# * `ARCH_EX1` for both min and max values measured within the 10 min span. Contains parameters of DataType FloatExtrem. (We will refer to it as EX Data.)
#
# There is a file for each day measured. File names are in `YYYYMMDD.BIN` format. Additionally, in the same directory there should be a file called `DESCFILE.INI`.

# %% [markdown]
# ## Running THIES BP locally
# This section shows the main functions of the THIES BP and how to use it to get a CSV file from a directory of binary data.

# %% [markdown]
# ### THIESData
# This class can read multiple .BIN files and export them as a single .CSV

# %%
from thiesBP import THIESData, THIESDayData

# %%
folder = './BINFILES/ARCH_AV1' # These are AV files

# Initialize THIESData object with datatype ('av' or 'ex') and folder path
data = THIESData('av', folder)

# %% [markdown]
# **Method 1**: Fast Read+Write Method
# * `.read_write(outpath: str)`: Takes filename (outpath) as input. Reads the path given and writes all BIN file data in same CSV. Does NOT save the data in a Pandas DataFrame.

# %%
data.read_write(outpath='output_filename1')
# Out:
# Data written in: data_uncompleted.csv

# %% [markdown]
# **Method 2**: Load into DF and then write CSV
# * `.load_df()`: Reads folder of .BIN files and transforms them into a Pandas DataFrame saved in the `.fullData` attribute.
# * `df2csv(outpath)`: Takes filename (outpath) as input. Writes into CSV file the contents of the DataFrame.

# %%
# 1 --- LOAD DATAFRAME ---
# Read all files and make DF
data.load_df()
print(data.shape)

# 1 --- (Optional) FILL MISSING TIMESTAMPS ---
# Completes times with Null (144 measurements per day, one every 10min)
data.load_df(complete_rows=True)
print(data.shape)

# 2 --- (Optional) FILL MISSING TIMESTAMPS ---
# Completes missing days with Null
# data.complete_empty_dates()
# print(data.shape)

# 3 --- WRITE DATA ---
# Write DF into CSV file
data.df2csv(outpath='output_filename2')
# Out:
# (432, 21)
# (432, 21)
# Data written in: output_filename2.csv

# %% [markdown]
# With this method we can access the data directly from this notebook.

# %%
data.fullData
# Out:
#            Date   Time  UBat Pressure PrTemp  Precipitation   WS    WD  \
# 0    2024/05/28  00:00  11.8   1011.4    5.4              0  0.8  66.5
# 1    2024/05/28  00:10  11.8   1011.2    5.4              0  0.4  41.2
# 2    2024/05/28  00:20  11.8   1011.0    5.4              0  0.6  52.7
# 3    2024/05/28  00:30  11.8   1010.9    5.4              0  0.6  93.1
# 4    2024/05/28  00:40  11.8   1010.8    5.4              0  0.6  26.7
# ..          ...    ...   ...      ...    ...            ...  ...   ...
# 427  2024/05/30  23:10  11.7   1014.1    8.2              0  0.1  41.8
# 428  2024/05/30  23:20  11.7   1013.9    8.2              0  0.8  51.3
# 429  2024/05/30  23:30  11.7   1013.9    8.1              0  0.4  60.4
# 430  2024/05/30  23:40  11.7   1013.7    8.1              0  0.9  37.3
# 431  2024/05/30  23:50  11.7   1013.7    8.1              0  0.6  89.0
#
#     WS std. dev. WD std. dev.  ... AirTemperature Radiation PicoMoisture 1  \
# 0            0.2         45.9  ...            2.5       0.5           None
# 1            0.2         48.3  ...            2.4       0.4           None
# 2            0.2         17.9  ...            2.5       0.4           None
# 3            0.2         50.8  ...            2.6       0.4           None
# 4            0.1         37.2  ...            2.6       0.5           None
# ..           ...          ...  ...            ...       ...            ...
# 427          0.2         31.6  ...            5.0      -0.1           None
# 428          0.3         25.8  ...            5.0      -0.1           None
# 429          0.3         47.6  ...            5.1      -0.1           None
# 430          0.2         22.4  ...            5.0      -0.1           None
# 431          0.2         65.8  ...            5.1      -0.2           None
#
#     PicoSoilTemp 1 PicoMoisture 2 PicoSoilTemp 2    CO2 UVA Radiation  \
# 0             None           None           None  515.9          -0.1
# 1             None           None           None  524.7          -0.1
# 2             None           None           None  531.0          -0.1
# 3             None           None           None  522.2          -0.1
# 4             None           None           None  527.0          -0.1
# ..             ...            ...            ...    ...           ...
# 427           None           None           None  519.1          -0.1
# 428           None           None           None  520.5          -0.1
# 429           None           None           None  518.1          -0.1
# 430           None           None           None  521.8          -0.1
# 431           None           None           None  518.3          -0.1
#
#     UVB Radiation  PAR Radiation
# 0               0           -0.8
# 1               0           -0.8
# 2               0           -0.8
# 3               0           -0.8
# 4               0           -0.8
# ..            ...            ...
# 427             0           -0.7
# 428             0           -0.7
# 429             0           -0.7
# 430             0           -0.7
# 431             0           -0.7
#
# [432 rows x 21 columns]

# %%
print(f'Shape of the DataFrame: {data.shape}')
print(f'Number of files read: {data.size}')
# Out:
# Shape of the DataFrame: (432, 21)
# Number of files read: 3

# %% [markdown]
# ### THIESDayData
# This class is made to handle a single .BIN file that represents the data of a single day.

# %%
# Example paths of individual (one day) files
path_bin_av = './BINFILES/ARCH_AV1/20240530.BIN'
path_bin_ex = './BINFILES/ARCH_EX1/20240530.BIN'
path_ini_av = './BINFILES/ARCH_AV1/DESCFILE.INI'
path_ini_ex = './BINFILES/ARCH_EX1/DESCFILE.INI'

# %% [markdown]
# #### Example 1: AV files

# %%
data1 = THIESDayData('av')
data1.read_binfile(path_bin_av, path_ini_av)
data1.info
data1
# Out:
# === THIES Day Data Instance ===
#
# Bytes per row (BPR): 99
# Bytes per parameter (BPP): 5
# Datatype: av
# Binfile: b'\x00\x00|a\x00C\x08;'...
# Descfile: {1: {'name': 'UBat', 'classid': 24, 'objectid': 874, 'offset': 0, 'size': 5, 'linkid': 213, 'unitid': 17, 'typeid': 14, 'avtype': 0}, 2: {'name': 'Pressure', 'classid': 24, 'objectid': 687, 'offset': 5, 'size': 5, 'linkid': 199, 'unitid': 5, 'typeid': 6, 'avtype': 0}, 3: {'name': 'PrTemp', 'classid': 24, 'objectid': 872, 'offset': 10, 'size': 5, 'linkid': 203, 'unitid': 3, 'typeid': 3, 'avtype': 0}, 4: {'name': 'Precipitation', 'classid': 24, 'objectid': 887, 'offset': 15, 'size': 5, 'linkid': 0, 'unitid': 9, 'typeid': 11, 'avtype': 0}, 5: {'name': 'WS', 'classid': 24, 'objectid': 1048, 'offset': 20, 'size': 5, 'linkid': 1550, 'pairref': 6, 'unitid': 1, 'typeid': 1, 'avtype': 0}, 6: {'name': 'WD
# 140  2024/05/30  23:20  11.7   1013.9    8.2              0  0.8  51.3
# 141  2024/05/30  23:30  11.7   1013.9    8.1              0  0.4  60.4
# 142  2024/05/30  23:40  11.7   1013.7    8.1              0  0.9  37.3
# 143  2024/05/30  23:50  11.7   1013.7    8.1              0  0.6  89.0
#
#     WS std. dev. WD std. dev.  ... AirTemperature Radiation PicoMoisture 1  \
# 0            0.1         20.8  ...            3.5      -0.3           None
# 1            0.2         16.3  ...            3.6      -0.2           None
# 2            0.2         28.5  ...            3.7      -0.2           None
# 3            0.3         21.5  ...            3.8      -0.1           None
# 4            0.3         23.4  ...            3.8      -0.2           None
# ..           ...          ...  ...            ...       ...            ...
# 139          0.2         31.6  ...            5.0      -0.1           None
# 140          0.3         25.8  ...            5.0      -0.1           None
# 141          0.3         47.6  ...            5.1      -0.1           None
# 142          0.2         22.4  ...            5.0      -0.1           None
# 143          0.2         65.8  ...            5.1      -0.2           None
#
#     PicoSoilTemp 1 PicoMoisture 2 PicoSoilTemp 2    CO2 UVA Radiation  \
# 0             None           None           None  472.3          -0.1
# 1             None           None           None  471.7          -0.1
# 2             None           None           None  470.5          -0.1
# 3             None           None           None  472.6          -0.1
# 4             None           None           None  474.4          -0.1
# ..             ...            ...            ...    ...           ...
# 139           None           None           None  519.1          -0.1
# 140           None           None           None  520.5          -0.1
# 141           None           None           None  518.1          -0.1
# 142           None           None           None  521.8          -0.1
# 143           None           None           None  518.3          -0.1
#
#     UVB Radiation  PAR Radiation
# 0               0           -0.8
# 1               0           -0.8
# 2               0           -0.8
# 3               0           -0.8
# 4               0           -0.8
# ..            ...            ...
# 139             0           -0.7
# 140             0           -0.7
# 141             0           -0.7
# 142             0           -0.7
# 143             0           -0.7
#
# [144 rows x 21 columns]

# %% [markdown]
# #### Example 2: EX files

# %%
data2 = THIESDayData('ex')
data2.read_binfile(path_bin_ex, path_ini_ex)
data2.info
data2
# Out:
# === THIES Day Data Instance ===
#
# Bytes per row (BPR): 292
# Bytes per parameter (BPP): 9
# Datatype: ex
# Binfile: b'\x00\x00|a\x00\xdb\xe1:'...
# Descfile: {1: {'name': 'UBat MIN', 'classid': 33, 'objectid': 964, 'offset': 0, 'size': 9, 'linkid': 213, 'extremid': 1, 'unitid': 17, 'typeid': 14, 'avtype': 0}, 2: {'name': 'UBat MAX', 'classid': 33, 'objectid': 1020, 'offset': 9, 'size': 9, 'linkid': 213, 'extremid': 2, 'unitid': 17, 'typeid': 14, 'avtype': 0}, 3: {'name': 'Pressure MIN', 'classid': 33, 'objectid': 625, 'offset': 18, 'size': 9, 'linkid': 199, 'extremid': 1, 'unitid': 5, 'typeid': 6, 'avtype': 0}, 4: {'name': 'Pressure MAX', 'classid': 33, 'objectid': 448, 'offset': 27, 'size': 9, 'linkid': 199, 'extremid': 2, 'unitid': 5, 'typeid': 6, 'avtype': 0}, 5: {'name': 'PrTemp MIN', 'classid': 33, 'objectid': 672, 'offset': 36, 'size': 9, 'linkid': 203, 'extremid': 1, '
'name': 'PicoMoisture 2 MIN', 'classid': 33, 'objectid': 329, 'offset': 180, 'size': 9, 'linkid': 320, 'extremid': 1, 'unitid': 4, 'typeid': 5, 'avtype': 0}, 22: {'name': 'PicoMoisture 2 MAX', 'classid': 33, 'objectid': 333, 'offset': 189, 'size': 9, 'linkid': 320, 'extremid': 2, 'unitid': 4, 'typeid': 5, 'avtype': 0}, 23: {'name': 'PicoSoilTemp 2 MIN', 'classid': 33, 'objectid': 345, 'offset': 198, 'size': 9, 'linkid': 337, 'extremid': 1, 'unitid': 3, 'typeid': 3, 'avtype': 0}, 24: {'name': 'PicoSoilTemp 2 MAX', 'classid': 33, 'objectid': 353, 'offset': 207, 'size': 9, 'linkid': 337, 'extremid': 2, 'unitid': 3, 'typeid': 3, 'avtype': 0}, 25: {'name': 'CO2 MIN', 'classid': 33, 'objectid': 854, 'offset': 216, 'size': 9, 'linkid': 762, 'extremid': 1, 'unitid': 21, 'typei ...
# N parameters: 32
# N Bytes: 42048
# Rows: 144
# Date: 2024/05/30
#            Date   Time UBat MIN UBat MAX Pressure MIN Pressure MAX PrTemp MIN  \
# 0    2024/05/30  00:00     11.7     11.7       1018.0       1018.3        6.5
# 1    2024/05/30  00:10     11.7     11.7       1018.1       1018.5        6.4
# 2    2024/05/30  00:20     11.7     11.7       1018.3       1018.6        6.4
# 3    2024/05/30  00:30     11.7     11.7       1018.4       1018.7        6.4
# 4    2024/05/30  00:40     11.7     11.7       1018.4       1018.8        6.4
# ..          ...    ...      ...      ...          ...          ...        ...
# 139  2024/05/30  23:10     11.7     11.7       1013.9       1014.3        8.2
# 140  2024/05/30  23:20     11.7     11.7       1013.7       1014.0        8.1
# 141  2024/05/30  23:30     11.7     11.7       1013.7       1014.0        8.1
# 142  2024/05/30  23:40     11.7     11.7       1013.2       1013.9        8.1
# 143  2024/05/30  23:50     11.7     11.7       1013.5       1013.8        8.0
#
#     PrTemp MAX WS MIN WS MAX gust  ... PicoSoilTemp 2 MIN PicoSoilTemp 2 MAX  \
# 0          6.6    0.5         1.2  ...               None               None
# 1          6.5    0.5         1.3  ...               None               None
# 2          6.5    0.4         1.5  ...               None               None
# 3          6.5    0.4         1.5  ...               None               None
# 4          6.5    0.3         1.6  ...               None               None
# ..         ...    ...         ...  ...                ...                ...
# 139        8.3    0.0         1.0  ...               None               None
# 140        8.2    0.0         1.3  ...               None               None
# 141        8.2    0.0         1.0  ...               None               None
# 142        8.1    0.5         1.3  ...               None               None
# 143        8.1    0.3         1.1  ...               None               None
#
#     CO2 MIN CO2 MAX UVA Radiation MIN UVA Radiation MAX UVB Radiation MIN  \
# 0     464.4   479.5              -0.1              -0.1                 0
# 1     466.3   477.4              -0.1              -0.1                 0
# 2     465.4   479.7              -0.1              -0.1                 0
# 3     463.8   485.2              -0.1              -0.1                 0
# 4     468.2   481.4              -0.1              -0.1                 0
# ..      ...     ...               ...               ...               ...
# 139   494.3   538.6              -0.1              -0.1                 0
# 140   509.5   533.2              -0.1              -0.1                 0
# 141   507.4   530.9              -0.1              -0.1                 0
# 142   516.8   528.1              -0.1              -0.1                 0
# 143   499.4   527.7              -0.1              -0.1                 0
#
#     UVB Radiation MAX PAR Radiation MIN PAR Radiation MAX
# 0                   0              -0.8              -0.7
# 1                   0              -0.8              -0.7
# 2                   0              -0.8              -0.7
# 3                   0              -0.8              -0.7
# 4                   0              -0.8              -0.7
# ..                ...               ...               ...
# 139                 0              -0.8              -0.7
# 140                 0              -0.8              -0.7
# 141                 0              -0.8              -0.7
# 142                 0              -0.8              -0.7
# 143                 0              -0.8              -0.7
#
# [144 rows x 34 columns]

# %% [markdown]
# EX files come with a timestamp for each measurement. These are saved separately in the `.datesDF` DataFrame.

# %%
# At what time was the MAX/MIN measurment taken (hh:mm)
data2.datesDF
# Out:
#            Date   Time UBat MIN UBat MAX Pressure MIN Pressure MAX PrTemp MIN  \
# 0    2024/05/30  00:00    23:50    23:50        23:53        23:59      23:51
# 1    2024/05/30  00:10    00:00    00:00        00:01        00:09      00:04
# 2    2024/05/30  00:20    00:10    00:11        00:14        00:18      00:10
# 3    2024/05/30  00:30    00:20    00:20        00:20        00:26      00:20
# 4    2024/05/30  00:40    00:30    00:31        00:31        00:38      00:30
# ..          ...    ...      ...      ...          ...          ...        ...
# 139  2024/05/30  23:10    23:00    23:00        23:09        23:04      23:00
# 140  2024/05/30  23:20    23:10    23:10        23:18        23:10      23:17
# 141  2024/05/30  23:30    23:20    23:20        23:20        23:25      23:20
# 142  2024/05/30  23:40    23:30    23:30        23:38        23:30      23:30
# 143  2024/05/30  23:50    23:40    23:40        23:48        23:40      23:44
#
#     PrTemp MAX WS MIN WS MAX gust  ... PicoSoilTemp 2 MIN PicoSoilTemp 2 MAX  \
# 0        23:50  23:54       23:57  ...               None               None
# 1        00:00  00:05       00:09  ...               None               None
# 2        00:10  00:18       00:13  ...               None               None
# 3        00:24  00:27       00:29  ...               None               None
# 4        00:30  00:36       00:31  ...               None               None
# ..         ...    ...         ...  ...                ...                ...
# 139      23:00  23:09       23:10  ...               None               None
# 140      23:10  23:19       23:15  ...               None               None
# 141      23:20  23:26       23:30  ...               None               None
# 142      23:30  23:36       23:39  ...               None               None
# 143      23:40  23:48       23:40  ...               None               None
#
#     CO2 MIN CO2 MAX UVA Radiation MIN UVA Radiation MAX UVB Radiation MIN  \
# 0     23:54   23:52             23:54             23:57             23:53
# 1     00:06   00:03             00:02             00:08             00:01
# 2     00:13   00:17             00:11             00:15             00:14
# 3     00:23   00:29             00:23             00:28             00:23
# 4     00:35   00:33             00:36             00:33             00:35
# ..      ...     ...               ...               ...               ...
# 139   23:00   23:05             23:00             23:08             23:00
# 140   23:18   23:11             23:17             23:16             23:18
# 141   23:22   23:27             23:24             23:28             23:23
# 142   23:39   23:33             23:36             23:33             23:30
# 143   23:50   23:46             23:49             23:44             23:50
#
#     UVB Radiation MAX PAR Radiation MIN PAR Radiation MAX
# 0               23:57             23:53             23:57
# 1               00:09             00:02             00:04
# 2               00:17             00:14             00:17
# 3               00:28             00:25             00:29
# 4               00:36             00:37             00:36
# ..                ...               ...               ...
# 139             23:06             23:00             23:04
# 140             23:13             23:18             23:12
# 141             23:27             23:25             23:21
# 142             23:32             23:30             23:32
# 143             23:44             23:49             23:47
#
# [144 rows x 34 columns]

# %% [markdown]
# ## Running THIES BP with Google Colab + Drive
# This section is for using the THIES BP notebook from Google Colab and using a data folder stored in a Google Drive account.

# %% [markdown]
# First, we will access Google Drive. This will open a window asking for permission to access the Drive account from Colab.

# %%
# !pip install -U -q bitarray

from google.colab import drive
drive.mount('/content/drive')
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 278.3/278.3 kB 11.2 MB/s eta 0:00:00

# %% [markdown]
# Make sure the name of the `DRIVEPATH` variable matches the path to the data folder to be read. In this example, the AV data folder's path is `THIESBP/ARCH_AV1`.

# %%
DRIVEPATH = '/content/drive/MyDrive/THIESBP/ARCH_AV1'

# %% [markdown]
# Additionally, we need access to the `thiesBP.py` file. If you have said file in Drive, update its corresponding PATH. In this example, the file is in the `THIESBP` folder.

# %%
import sys
sys.path.append('/content/drive/MyDrive/THIESBP')

from thiesBP import THIESData, THIESDayData

# %% [markdown]
# Now we are ready to use the THIES BP tools to read binary files.

# %%
# Initialize THIESData object with datatype ('av' or 'ex') and DRIVEPATH
data = THIESData('av', DRIVEPATH)

# %% [markdown]
# **Method 1**: Fast Read+Write Method
# * `.read_write(outpath: str)`: Takes filename (outpath) as input. Reads the path given and writes all BIN file data in same CSV. Does NOT save the data in a Pandas DataFrame.

# %%
# We will save the new file in the same folder
OUTPATH = '/content/drive/MyDrive/THIESBP/output_file'

data.read_write(outpath=OUTPATH)

# %% [markdown]
# **Method 2**: Load into DF and then write CSV
# * `.load_df()`: Reads folder of .BIN files and transforms them into a Pandas DataFrame saved in the `.fullData` attribute.
# * `df2csv(outpath)`: Takes filename (outpath) as input. Writes into CSV file the contents of the DataFrame.

# %%
# 1 --- LOAD DATAFRAME ---
# Read all files and make DF
data.load_df()
print(data.shape)

# 1 --- (Optional) FILL MISSING TIMESTAMPS ---
# Completes times with Null (144 measurements per day, one every 10min)
# data.load_df(complete_rows=True)
# print(data.shape)

# 2 --- (Optional) FILL MISSING TIMESTAMPS ---
# Completes missing days with Null
# data.complete_empty_dates()
# print(data.shape)

# 3 --- WRITE DATA ---
# Write DF into CSV file
data.df2csv(outpath=OUTPATH)

# %%
data.fullData

# %% [markdown]
# # Visualizations

# %%
import matplotlib.pyplot as plt

df = data1.dataDF
df2 = data2.dataDF

idx = df2['Time']

plt.figure(figsize=(10, 6))
plt.plot(idx, df2['AirTemperature MAX'], linestyle='--', color='r', label='MAX Temp', lw=0.6)
plt.plot(idx, df2['AirTemperature MIN'], linestyle='--', color='b', label='MIN Temp', lw=0.6)
plt.plot(idx, df['AirTemperature'], linestyle='-', color='g', label='AV Temp')
plt.title(f'Air Temperature Over Time: {data1.date}')
plt.xlabel('Time')
plt.ylabel('Air Temperature (°C)')

num_dates_to_show = 12
plt.xticks(idx[::len(df)//num_dates_to_show], rotation=0)  # Show every n-th date

plt.grid()
plt.legend()
plt.tight_layout()
plt.show()
